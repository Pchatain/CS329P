# %%
import os
import random
import numpy as np
import pandas as pd
from collections import defaultdict
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import gc
import lightgbm as lgb
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score, log_loss, confusion_matrix, accuracy_score, roc_auc_score, roc_curve
# %pwd
# %cd /Users/wenxindong/Desktop/Stanford/CS329P/project/riiid-test-answer-prediction
# %cd /Users/peterchatain/Documents/Classes/CS329P/project/riiid-test-answer-prediction
# %ls
# Out:
# /Users/wenxindong/Desktop/Stanford/CS329P/project/riiid-test-answer-prediction
# AutogluonModels/                       cv1_valid.pickle.zip
# autogl_soft_label.pickle               cv1_valid_100k.pickle
# cv1_train.pickle                       example_sample_submission.csv
# cv1_train.pickle.zip                   example_test.csv
# cv1_train_10000k.pickle                lectures.csv
# cv1_train_10000k_preprocessed.pickle   questions.csv
# cv1_train_1000k.pickle                 riiid-test-answer-prediction.zip
# cv1_train_1000k_preprocessed.pickle    riiideducation/
# cv1_train_100k.pickle                  test_4920_users.pickle
# cv1_train_100k_preprocessed.pickle     test_4920_users_preprocessed.pickle
# cv1_train_preprocessed.pickle          train.csv
# cv1_val_100k_preprocessed.pickle       train_39360_users.pickle
# cv1_val_10k.pickle                     train_39360_users_preprocessed.pickle
# cv1_val_10k_preprocessed.pickle        valid_4920_users.pickle
# cv1_val_preprocessed.pickle            valid_4920_users_preprocessed.pickle
# cv1_valid.pickle

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ### Load data

# %%
train_pickle = 'train_39360_users_preprocessed.pickle'  #about one tenth of the training dataset
valid_pickle = 'valid_4920_users_preprocessed.pickle'  
test_pickle = "test_4920_users_preprocessed.pickle"
question_file = 'questions.csv'

# Read data
train = pd.read_pickle(train_pickle)
valid = pd.read_pickle(valid_pickle)
test = pd.read_pickle(test_pickle)

questions_df = pd.read_csv(question_file)
train = train.fillna(0)
valid = valid.fillna(0)
test = test.fillna(0)

#subsample
train = train[:len(train)//10]
valid = valid[:len(valid)//10]
test = test[:len(test)//10]

for i in range(1,8):
  train['part'+str(i)] = (train["part"]==i)
  valid['part'+str(i)] = (valid["part"]==i)
  test['part'+str(i)] = (test["part"]==i)

#get labels
TARGET = 'answered_correctly'
train_x = train.drop([TARGET, 'part'], axis = 1)
valid_x = valid.drop([TARGET, 'part'], axis = 1)
test_x = test.drop([TARGET, 'part'], axis = 1)

train_y = train[TARGET]
valid_y = valid[TARGET]
test_y = test[TARGET]

# %%
#valid_x = valid_x.drop(["prior_question_elapsed_time", "answered_correctly_uq_count", "explanation_u_avg", "timestamp_u_incorrect_recency", "explanation_q_avg", "prior_question_had_explanation","part", "timestamp_u_recency_3", "timestamp_u_recency_2", "timestamp_u_recency_1"], axis=1)
mu = train_x.mean()
sigmaa = train_x.std()

train_x = (train_x - mu)/ sigmaa
valid_x = (valid_x - mu)/ sigmaa
test_x = (test_x - mu)/ sigmaa

print(train_x.shape, train_y.shape)
print(valid_x.shape, valid_y.shape)
print(test_x.shape, test_y.shape)

# train_x.describe()
# Out:
# (989711, 20) (989711,)
# (126725, 20) (126725,)
# (119116, 20) (119116,)

# %%
print(np.mean(train_y))
print(np.mean(valid_y))
# Out:
# 0.67302677246186
# 0.6656460840402446

# %%
test_x
# Out:
#         prior_question_elapsed_time  prior_question_had_explanation  \
# 0                         -0.003419                       -3.050757
# 1                         -0.376872                       -3.050757
# 2                         -0.022740                       -3.050757
# 3                         -0.225101                       -3.050757
# 4                         -0.478053                       -3.050757
# ...                             ...                             ...
# 119111                    -0.731005                        0.327787
# 119112                    -0.174511                        0.327787
# 119113                    -0.478053                        0.327787
# 119114                    -0.629824                        0.327787
# 119115                    -0.073331                        0.327787
#
#         answered_correctly_u_avg  elapsed_time_u_avg  explanation_u_avg  \
# 0                      -4.711462           -3.533400          -2.822415
# 1                       2.483475           -0.028677          -2.822415
# 2                      -1.113994           -0.538323          -2.822415
# 3                      -2.313150           -0.386020          -2.822415
# 4                      -1.113994           -0.447947          -2.822415
# ...                          ...                 ...                ...
# 119111                  0.443965           -1.055078          -0.235470
# 119112                  0.403688           -1.062573          -0.228662
# 119113                  0.364036           -1.058179          -0.221960
# 119114                  0.380340           -1.060224          -0.215361
# 119115                  0.341471           -1.065401          -0.208863
#
#         answered_correctly_q_avg  elapsed_time_q_avg  explanation_q_avg  \
# 0                       0.782602           -0.069762          -3.440969
# 1                      -1.122513           -0.300905          -3.251173
# 2                      -1.399762           -0.243658          -3.188296
# 3                      -0.058348           -0.233821          -3.505954
# 4                      -0.119406           -0.742277          -3.334731
# ...                          ...                 ...                ...
# 119111                 -0.160273           -0.779784           0.419083
# 119112                  1.291629           -0.754746           0.356305
# 119113                  0.385386           -0.777994           0.388926
# 119114                  0.334805           -0.253683           0.366279
# 119115                  0.440063           -0.279513           0.452123
#
#         answered_correctly_uq_count  timestamp_u_recency_1  \
# 0                         -0.330749              -0.039675
# 1                         -0.330749              -0.039620
# 2                         -0.330749              -0.039629
# 3                         -0.330749              -0.039640
# 4                         -0.330749              -0.039425
# ...                             ...                    ...
# 119111                    -0.330749              -0.039618
# 119112                    -0.330749              -0.039631
# 119113                    -0.330749              -0.039637
# 119114                    -0.330749               0.056235
# 119115                    -0.330749              -0.039639
#
#         timestamp_u_recency_2  timestamp_u_recency_3  \
# 0                   -0.054997              -0.066727
# 1                   -0.054997              -0.066727
# 2                   -0.054926              -0.066727
# 3                   -0.054940              -0.066648
# 4                   -0.054797              -0.066535
# ...                       ...                    ...
# 119111              -0.054935              -0.066654
# 119112              -0.054926              -0.066649
# 119113              -0.054940              -0.066646
# 119114               0.012568              -0.011095
# 119115               0.012567              -0.011100
#
#         timestamp_u_incorrect_recency     part1     part2     part3     part4  \
# 0                           -0.068082  3.458042 -0.484880 -0.312125 -0.302921
# 1                           -0.068082  3.458042 -0.484880 -0.312125 -0.302921
# 2                           -0.068055  3.458042 -0.484880 -0.312125 -0.302921
# 3                           -0.068061 -0.289181  2.062365 -0.312125 -0.302921
# 4                           -0.067915 -0.289181 -0.484880  3.203846 -0.302921
# ...                               ...       ...       ...       ...       ...
# 119111                      -0.067979 -0.289181  2.062365 -0.312125 -0.302921
# 119112                      -0.068056 -0.289181  2.062365 -0.312125 -0.302921
# 119113                      -0.068060 -0.289181  2.062365 -0.312125 -0.302921
# 119114                      -0.012012  3.458042 -0.484880 -0.312125 -0.302921
# 119115                      -0.068061  3.458042 -0.484880 -0.312125 -0.302921
#
#           part5     part6     part7
# 0      -0.81691 -0.351581 -0.227956
# 1      -0.81691 -0.351581 -0.227956
# 2      -0.81691 -0.351581 -0.227956
# 3      -0.81691 -0.351581 -0.227956
# 4      -0.81691 -0.351581 -0.227956
# ...         ...       ...       ...
# 119111 -0.81691 -0.351581 -0.227956
# 119112 -0.81691 -0.351581 -0.227956
# 119113 -0.81691 -0.351581 -0.227956
# 119114 -0.81691 -0.351581 -0.227956
# 119115 -0.81691 -0.351581 -0.227956
#
# [119116 rows x 20 columns]

# %% [markdown]
# ## Linear classifier baseline

# %%
from sklearn.linear_model import LogisticRegression
def linear_lr(X_train, Y_train, max_iter=500):
    model = LogisticRegression()
    model.fit(X_train, Y_train)
    return model
def predict_score(model, X_test, Y_test):
    prediction = model.predict(X_test)
    prediction_val_proba = model.predict_proba(X_test)
    prediction_val_final = model.predict(X_test)
    loss = log_loss(Y_test, prediction_val_proba[:,1])
    accuracy = accuracy_score(Y_test, prediction_val_final)
    auc = roc_auc_score(Y_test, prediction_val_proba[:,1])
    return loss, accuracy, auc

clf = linear_lr(train_x, train_y, max_iter=500)
loss, acc, auc = predict_score(clf, train_x, train_y)
print(f"accuracy: {acc}, auc: {auc}")

loss, acc, auc = predict_score(clf, valid_x, valid_y)
print(f"accuracy: {acc}, auc: {auc}")
# Out:
# accuracy: 0.6598509030461874, auc: 0.6663731265139432
# accuracy: 0.6939220885172344, auc: 0.717889655904135

# %%
train_x.columns
# Out:
# Index(['prior_question_elapsed_time', 'prior_question_had_explanation',
#        'answered_correctly_u_avg', 'elapsed_time_u_avg', 'explanation_u_avg',
#        'answered_correctly_q_avg', 'elapsed_time_q_avg', 'explanation_q_avg',
#        'answered_correctly_uq_count', 'timestamp_u_recency_1',
#        'timestamp_u_recency_2', 'timestamp_u_recency_3',
#        'timestamp_u_incorrect_recency', 'part1', 'part2', 'part3', 'part4',
#        'part5', 'part6', 'part7'],
#       dtype='object')

# %%
import shap

X_train = np.array(train_x)
X_test = np.array(valid_x)

def getShapValues(model, X_train, X_test, background=100, explain = 20, nsamples=100):
    shap.initjs()
    '''use 1000 examples as background data'''
    background_data_idxs = np.random.choice(len(X_train), (background,))
    print(background_data_idxs)
    '''use 200 examples as data to be explained'''
    test_data_idxs = np.random.choice(len(X_test), (explain,))
    X_explained = X_test[test_data_idxs,:]
    print(test_data_idxs)
    explainer = shap.KernelExplainer(model.predict_proba, X_train[background_data_idxs, :])
    shap_values = explainer.shap_values(X_explained, nsamples=nsamples)
    return shap_values, explainer, X_explained

shap_values, explainer, X_explained = getShapValues(clf, X_train, X_test, background=800, explain = 200, nsamples=800) #shap_value = [#class,  #explain, #features]

top_n_features = 10

def shap_ranking(shap_values, test, top_n_features, legend, features):

    plt.figure(figsize=(5,5))
    shap.summary_plot(shap_values, test, features, class_names=legend, max_display = top_n_features, show =False)
    shap_total = np.sum(np.abs(np.array(shap_values)), axis = (0, 1))/(len(shap_values[0])*len(shap_values))
    shap_ranked_features = { x:v for v, x in sorted(zip(shap_total, list(train_x.columns)), reverse = True) }
    plt.title("Features ranked by SHAP values (top {}) ".format(top_n_features))
    plt.show()
    return shap_ranked_features
    
print("Binary Classification")
shap_ranked_features =  shap_ranking(shap_values, X_test, 20, ["Incorrect", "Correct"], list(train_x.columns))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# Using

# num_full_subsets = 1
# remaining_weight_vector = [0.214078   0.15111388 0.12041888 0.10275744 0.09174772 0.0846902
#  0.08027925 0.07784655 0.07706808]
# num_paired_subset_sizes = 9
# weight_left = 0.7032951454518925
# np.sum(w_aug) = 20.0
# np.sum(self.kernelWeights) = 1.0
# phi = [ 0.         -0.01249851 -0.04724067  0.0263455   0.         -0.14722602
#   0.02391475  0.0070933  -0.05663388  0.          0.          0.
#   0.          0.          0.          0.          0.         -0.005177
#  -0.02178738  0.        ]
# np.sum(w_aug) = 20.0
# np.sum(self.kernelWeights) = 1.0
# phi = [ 0.          0.01249851  0.04724067 -0.0263455   0.          0.14722602
#  -0.02391475 -0.0070933   0.05663388  0.          0.          0.
#   0.          0.          0.          0.          0.          0.005177
#   0.02178738  0.        ]
# num_full_subsets = 1
# remaining_weight_vector = [0.214078   0.15111388 0.12041888 0.10275744 0.09174772 0.0846902
#  0.08027925 0.07784655 0.07706808]
# num_paired_subset_sizes = 9
# weight_left = 0.7032951454518925
# np.sum(w_aug) = 20.0
# np.sum(self.kernelWeights) = 0.9999999999999998
# phi = [ 0.00277953 -0.01601863  0.00377692  0.          0.00154905 -0.09934363
#   0.          0.00782258  0.01647376  0.          0.          0.
#   0.          0.          0.          0.          0.          0.00978025
#   0.00276375  0.00371808]
# np.sum(w_aug) = 20.0
# np.sum(self.kernelWeights) = 0.9999999999999998
# phi = [-0.00277953  0.01601863 -0.00377692  0.         -0.00154905  0.09934363
#   0.         -0.00782258 -0.01647376  0.          0.          0.
#   0.          0.          0.          0.          0.         -0.00978025
#  -0.00276375 -0.00371808]
# num_full_subsets = 1
# remaining_weight_vector = [0.214078   0.15111388 0.12041888 0.10275744 0.09174772 0.0846902
#  0.08027925 0.07784655 0.07706808]
# num_paired_subset_sizes = 9
# weight_left = 0.7032951454518925
# np.sum(w_aug) = 19.999999999999996
# np.sum(self.kernelWeights) = 0.9999999999999998
# phi = [ 0.         -0.01653876  0.034543    0.03611644  0.00261379 -0.06051857
#   0.          0.00923656  0.01781032  0.          0.          0.
#   0.          0.          0.          0.          0.          0.01052888
#   0.00312965  0.00430147]
# np.sum(w_aug) = 19.999999999999996
# np.sum(self.kernelWeights) = 0.9999999999999998
# phi = [ 0.          0.01653876 -0.034543   -0.03611644 -0.00261379  0.06051857
#   0.         -0.00923656 -0.01781032  0.          0.          0.
#   0.          0.          0.          0.          0.         -0.01052888
#  -0.00312965 -0.00430147]
# num_full_subsets = 1
# remaining_weight_vector = [0.214078   0.15111388 0.12041888 0.10275744 0.09174772 0.0846902
#  0.08027925 0.07784655 0.07706808]
# num_paired_subset_sizes = 9
# weight_left = 0.7032951454518925
# np.sum(w_aug) = 20.0
# np.sum(self.kernelWeights) = 1.0
# phi = [ 0.         -0.01421956 -0.04861895  0.          0.          0.17646817
#   0.11896533  0.0095626   0.0199707   0.          0.          0.
#   0.          0.          0.          0.          0.         -0.00647245
#   0.         -0.08509971]
# np.sum(w_aug) = 20.0
# np.sum(self.kernelWeights) = 1.0
# phi = [ 0.          0.01421956  0.04861895  0.          0.         -0.17646817
#  -0.11896533 -0.0095626  -0.0199707   0.          0.          0.
#   0.          0.          0.          0.          0.          0.00647245
#   0.          0.08509971]
# Binary Classification

# %%
print("Binary Classification")
shap_ranked_features =  shap_ranking(shap_values, X_test, 20, ["Incorrect", "Correct"], list(train_x.columns))
# Out:
# Binary Classification

# %%
shap_ranked_features.keys()

# {'answered_correctly_q_avg': 0.0996315929596451,
#  'answered_correctly_u_avg': 0.04273608541461067,
#  'answered_correctly_uq_count': 0.024798484828128915,
#  'prior_question_had_explanation': 0.01673373404019183,
#  'elapsed_time_q_avg': 0.011791286441935469,
#  'elapsed_time_u_avg': 0.009237697618582884,
#  'explanation_q_avg': 0.008396671071433614,
#  'part7': 0.004160145995801056,
#  'part5': 0.003493953696173882,
#  'part6': 0.002180513609968638,
#  'prior_question_elapsed_time': 0.0020044712398613732,
#  'part4': 0.001258921504394816,
#  'part1': 0.0006998075867737023,
#  'part2': 0.0005430864567064415,
#  'explanation_u_avg': 0.0005159138860880801,
#  'timestamp_u_incorrect_recency': 0.00031972146438875984,
#  'timestamp_u_recency_3': 0.0003007577308920089,
#  'part3': 7.643744431635882e-05,
#  'timestamp_u_recency_2': 6.409631950669805e-05,
#  'timestamp_u_recency_1': 6.120554261839536e-05}
# Out:
# dict_keys(['answered_correctly_q_avg', 'answered_correctly_u_avg', 'prior_question_had_explanation', 'answered_correctly_uq_count', 'elapsed_time_q_avg', 'explanation_q_avg', 'elapsed_time_u_avg', 'part5', 'part7', 'part6', 'prior_question_elapsed_time', 'explanation_u_avg', 'part4', 'part2', 'part1', 'timestamp_u_incorrect_recency', 'part3', 'timestamp_u_recency_3', 'timestamp_u_recency_1', 'timestamp_u_recency_2'])

# %% [markdown]
# ## Decision tree classifier baseline

# %%
def decision_tree(X_train, Y_train, max_depth=20):
    model = DecisionTreeClassifier(random_state=0,max_depth=max_depth)
    model.fit(X_train, Y_train)
    return model
clf = decision_tree(train_x, train_y, max_depth=6)
loss, acc, auc = predict_score(clf, test_x, test_y)
print(f"accuracy: {acc}, auc: {auc}")
# Out:
# accuracy: 0.7255112663286208, auc: 0.7489161941097908

# %% [markdown]
# ### Autogloun baselines

# %%
#TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211209_205024/")

from autogluon.tabular import TabularDataset, TabularPredictor
data_train = train_x
data_train["label"] = train_y
data_train = TabularDataset(data_train) 

data_valid = valid_x
data_valid["label"] = valid_y
data_valid = TabularDataset(data_valid) 


data_test = test_x
data_test["label"] = test_y
data_test = TabularDataset(data_test) 

predictor = TabularPredictor(label="label", eval_metric = "roc_auc").fit(data_train, tuning_data =data_valid, ag_args_fit= {"num_gpus":0}, hyperparameters = {
"NN": {},  "CAT": {}, "FASTAI": {}, "RF":{},'XT':{}, "KNN":{}})
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211211_013103/"
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (989711 samples, 174.19 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20211211_013103/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    989711
# Train Data Columns: 20
# Tuning Data Rows:    126725
# Tuning Data Columns: 20
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6461.14 MB
# 	Train Data (Original)  Memory Usage: 178.63 MB (2.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 20 | ['prior_question_elapsed_time', 'prior_question_had_explanation', 'answered_correctly_u_avg', 'elapsed_time_u_avg', 'explanation_u_avg', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 12 | ['prior_question_elapsed_time', 'answered_correctly_u_avg', 'elapsed_time_u_avg', 'explanation_u_avg', 'answered_correctly_q_avg', ...]
# 		('int', ['bool']) :  8 | ['prior_question_had_explanation', 'part1', 'part2', 'part3', 'part4', ...]
# 	4.2s = Fit runtime
# 	20 features in original data used to generate 20 features in processed data.
# 	Train Data (Processed) Memory Usage: 116.11 MB (1.7% of available memory)
# Data preprocessing and feature engineering runtime = 5.14s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric argument of fit()
# Fitting 6 L1 models ...
# Fitting model: KNeighbors ...
# 	0.6719	 = Validation score   (roc_auc)
# 	8.22s	 = Training   runtime
# 	181.69s	 = Validation runtime
# Fitting model: RandomForest ...
# 	Warning: Model is expected to require 116.21% of available memory...
# 	Not enough memory to train RandomForest... Skipping this model.
# Fitting model: CatBoost ...
# 	0.768	 = Validation score   (roc_auc)
# 	68.01s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTrees ...
# 	Warning: Model is expected to require 223.22% of available memory...
# 	Not enough memory to train ExtraTrees... Skipping this model.
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 2: early stopping
# 	0.7533	 = Validation score   (roc_auc)
# 	746.77s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	0.7684	 = Validation score   (roc_auc)
# 	1609.97s	 = Training   runtime
# 	3.47s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.77	 = Validation score   (roc_auc)
# 	15.59s	 = Training   runtime
# 	0.04s	 = Validation runtime
# AutoGluon training complete, total runtime = 2862.49s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211211_013103/")

# %%
best_model = predictor.get_model_best()
print("best model is ", best_model)
result = predictor.evaluate(data_test)
# Out:
# best model is  WeightedEnsemble_L2
# Evaluation: roc_auc on test data: 0.7731340730039526
# Evaluations on test data:
# {
#     "roc_auc": 0.7731340730039526,
#     "accuracy": 0.7375163705967293,
#     "balanced_accuracy": 0.6617159993741086,
#     "mcc": 0.3641331099879136,
#     "f1": 0.8187247069191433,
#     "precision": 0.7639440399034872,
#     "recall": 0.8819686465554931
# }

# %%
distilled_models = predictor.distill(data_train, tuning_data=data_valid)
# Out:
# Distilling with teacher='WeightedEnsemble_L2', teacher_preds=soft, augment_method=spunge ...
# SPUNGE: Augmenting training data with 100000 synthetic samples for distillation...
# Distilling with each of these student models: ['LightGBM_DSTL', 'NeuralNetMXNet_DSTL', 'CatBoost_DSTL', 'RandomForestMSE_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...

# %% [markdown]
# ## soft labels from autogluon

# %%
autogl_predict_proba = predictor.predict_proba(data_train)

# %%
pd.to_pickle(autogl_predict_proba,"autogl_soft_label.pickle")

# %%
autogl_predict_proba = pd.read_pickle("autogl_soft_label.pickle")

# %%
autogl_predict_proba = autogl_predict_proba[1]

# %%
autogl_predict_proba
# Out:
# 0         0.640832
# 1         0.546276
# 2         0.559002
# 3         0.489114
# 4         0.411639
#             ...
# 989706    0.801175
# 989707    0.435490
# 989708    0.898390
# 989709    0.785813
# 989710    0.975181
# Name: 1, Length: 989711, dtype: float64

# %% [markdown]
# ## Soft labels from transformer

# %% [markdown]
# ## Soft labels from LSTM

# %% [markdown]
# ## Train soft decision tree

# %%
#Load data
#Note that we will not use Long since y will represent probability (at least in the future)
t_train_x = torch.tensor(np.array(train_x), dtype=torch.float64, device=device, requires_grad=False)
t_train_y = torch.tensor(np.array(train_y), dtype=torch.float64, device=device, requires_grad=False)

t_valid_x = torch.tensor(np.array(valid_x), dtype=torch.float64, device=device, requires_grad=False)
t_valid_y = torch.tensor(np.array(valid_y), dtype=torch.float64, device=device, requires_grad=False)

t_test_x = torch.tensor(np.array(test_x), dtype=torch.float64, device=device, requires_grad=False)
t_test_y = torch.tensor(np.array(test_y), dtype=torch.float64, device=device, requires_grad=False)

# %%
t_train_x
# Out:
# tensor([[-3.4186e-03, -3.0508e+00, -4.7115e+00,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [ 1.7962e-01, -3.0508e+00, -4.7115e+00,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [-1.7451e-01, -3.0508e+00, -4.7115e+00,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         ...,
#         [-1.2392e-01, -3.0508e+00,  1.8420e-01,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [-2.7569e-01,  3.2779e-01,  1.8476e-01,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [-1.2392e-01,  3.2779e-01,  1.8358e-01,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01]], dtype=torch.float64)

# %%
t_test_x
# Out:
# tensor([[-3.4186e-03, -3.0508e+00, -4.7115e+00,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [-3.7687e-01, -3.0508e+00,  2.4835e+00,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [-2.2740e-02, -3.0508e+00, -1.1140e+00,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         ...,
#         [-4.7805e-01,  3.2779e-01,  3.6404e-01,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [-6.2982e-01,  3.2779e-01,  3.8034e-01,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01],
#         [-7.3331e-02,  3.2779e-01,  3.4147e-01,  ..., -8.1691e-01,
#          -3.5158e-01, -2.2796e-01]], dtype=torch.float64)

# %% [markdown]
# ### Training helper functions

# %%
def initialize_layers(input_dim, max_depth):
  Layers = dict()
  Layers['W'] = torch.randn((input_dim, ((2**max_depth)-1)), dtype=torch.float64, device=device, requires_grad=True)
  Layers['b'] = torch.randn((((2**max_depth)-1), ), dtype=torch.float64, device=device, requires_grad=True)
  Layers['p'] = torch.randn((2**max_depth, ), dtype=torch.float64, device=device, requires_grad=True)
  m = dict()
  v = dict()
  g = dict()
  mh = dict()
  vh = dict()
  for namee in Layers.keys():
    m[namee] = torch.zeros_like(Layers[namee])
    v[namee] = torch.zeros_like(Layers[namee])
    g[namee] = torch.zeros_like(Layers[namee])
    mh[namee] = torch.zeros_like(Layers[namee])
    vh[namee] = torch.zeros_like(Layers[namee])

  return Layers, m, v, g, mh, vh

# %%
def forward(input, Layers, max_depth=None, requires_grad=True):
  if requires_grad:
    temp = torch.sigmoid(input@Layers['W']+Layers['b'])
  else:
    temp = torch.sigmoid(input@Layers['W'].data+Layers['b'].data)
  dist = None
  if max_depth == None:
    max_depth = int(np.round(np.log(Layers['W'].shape[1]+1)/np.log(2)))
  for i in range(max_depth):
    if dist == None:
      dist = torch.cat((temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1), (1-temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1))), dim=2).reshape(input.shape[0],-1).unsqueeze(-1).repeat(1,1,2**(max_depth-1-i)).reshape(input.shape[0],-1)
    else:
      dist *= torch.cat((temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1), (1-temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1))), dim=2).reshape(input.shape[0],-1).unsqueeze(-1).repeat(1,1,2**(max_depth-1-i)).reshape(input.shape[0],-1)
  if requires_grad:
    score = dist@Layers['p']
  else:
    score = dist@Layers['p'].data
  prob = torch.sigmoid(score)
  return prob

# %%
#Note that the output is torch
def find_loss(prob, output):
  loss = - (torch.log(prob)@output + torch.log(1-prob)@(1-output)) / output.shape[0]
  return loss

#Note that the output is torch
def find_accuracy(prob, output):
  acc = torch.mean(((2*(prob>=0.5)-1)*(2*(output>=0.5)-1)+1)/2)
  return acc
  
def find_auc (prob, output):
  auc = roc_auc_score((output>=0.5),prob)
  return auc

def predict(prob, threshold=0.5):
  return (prob>=threshold)

def find_TPR_FPR(prob, output, threholsd_part=1e-2):
  TRPs = []
  FPRs = []

  for i in range(1, int(1 / threholsd_part)):
    threshold = threholsd_part*i
    temp = predict(prob, threshold=threshold) + 2*predict(output, threshold=0.5)
    FP = np.sum(temp==1)
    TP = np.sum(temp==3)
    FN = np.sum(temp==2)
    TN = np.sum(temp==0)
    TPR = TP / (TP+FN)
    FPR = FP / (FP+TN)
    TRPs.append(TPR)
    FPRs.append(FPR)

  FPRs = np.array(FPRs)
  TRPs = np.array(TRPs)

  return TRPs, FPRs

def find_roc_auc_after_training(t_valid_x, t_valid_y, Layers, threholsd_part=1e-2):
  prob = forward(t_valid_x, Layers, max_depth=None, requires_grad=False).cpu().detach().numpy()
  output = t_valid_y.cpu().detach().numpy()
  return find_auc(prob, output, threholsd_part=1e-2)

def find_auc(prob, output, epsilon=1e-5, plott=True, threholsd_part=1e-2):
    #threholsd_part = 0.1
    u = 1
    l = 0
    auc = 0
    while u-l >= epsilon:
      threholsd_part *= 1e-1
      
      TRPs, FPRs = find_TPR_FPR(prob, output, threholsd_part=threholsd_part)

      difference = np.append(1, FPRs) - np.append(FPRs, 0)
      u = difference[:-1]@TRPs
      l = difference[1:]@TRPs
                                                  
      auc = (difference[:-1]@TRPs + difference[1:]@TRPs)/2
    if plott:
      plt.fill_between(FPRs, TRPs, alpha=0.5, color='yellow')
      plt.plot([0,1],[0,1], '--', color='green')
      plt.xlabel("FPR")
      plt.ylabel("TPR")
      plt.title("AUC-ROC Curve")

      plt.show()

    return auc

# %%
def print_progress(Layers, t_train_x, t_train_y, t_valid_x, t_valid_y, max_depth=None, epoch_index=None, verbose=True):
  #Eval Train
  prob = forward(t_train_x, Layers, max_depth=max_depth, requires_grad=False)
  train_loss = float(find_loss(prob, t_train_y))
  train_acc = float(find_accuracy(prob, t_train_y))
  if verbose:
    if epoch_index != None:
      print('\nEpoch ' + str(epoch_index) + ' Summary:')
    print('Train Loss: ' + str(train_loss))
    print('Train Accuracy: ' + str(int(10000*train_acc)/100) + '%')

  #Eval Valid
  prob = forward(t_valid_x, Layers, max_depth=max_depth, requires_grad=False)
  val_loss = float(find_loss(prob, t_valid_y))
  val_acc = float(find_accuracy(prob, t_valid_y))
  if verbose:
    print('Valid Loss: ' + str(val_loss))
    print('Valid Accuracy: ' + str(int(10000*val_acc)/100) + '%')

  return train_loss, train_acc, val_loss, val_acc

# %%
def soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask=None, pretrained_Layers=None, step_size=1e-3, reg_l=1e-3, minibatch_size=128, num_epoch=20, num_step_per_epoch=320, beta1=0.9, beta2=0.999, epsilon=1e-8, verbose=False, graphing=False):
  #Initialization phrase
  t = 0
  
  Layers, m, v, g, mh, vh = initialize_layers(t_train_x.shape[1], max_depth)

  if pretrained_Layers != None:
    Layers = pretrained_Layers

  #Record
  loss_array = np.zeros(0)
  acc_array = np.zeros(0)
  val_loss_array = np.zeros(0)
  val_acc_array = np.zeros(0)

  #Place Mask if applicable
  if mask != None:
    Layers['W'].data *= mask

  if verbose:
    print("\nStart training\n")

    print('# of Epochs: ' + str(num_epoch))
    print('# of Steps per Epoch: ' + str(num_step_per_epoch))
    print('Minibatch Size: ' + str(minibatch_size))

  for epoch_index in range(num_epoch):
    #Print progress
    train_loss, train_acc, val_loss, val_acc = print_progress(Layers, t_train_x, t_train_y, t_valid_x, t_valid_y, max_depth=max_depth, epoch_index=epoch_index, verbose=verbose)
    loss_array= np.append(loss_array, train_loss)
    acc_array = np.append(acc_array, train_acc)
    val_loss_array= np.append(val_loss_array, val_loss)
    val_acc_array = np.append(val_acc_array, val_acc)
    for step_index in range(num_step_per_epoch):
      #Minibatch
      index = torch.randperm(t_train_x.shape[0])[:minibatch_size]

      #Forward
      prob = forward(t_train_x[index], Layers, max_depth=max_depth, requires_grad=True)
      loss = find_loss(prob, t_train_y[index])

      #Reg
      reg = reg_l * torch.mean(torch.abs(Layers['W']))
      reg_w = 1e-1
      reg_atten = 1e-2
      for i in range(max_depth):
        reg_w *= reg_atten
        vector_size = np.int(np.power(2, i))
        num_pairs = np.int(np.power(2, (max_depth-i-1)))
        for ii in range(num_pairs):
          reg += reg_w * torch.linalg.norm(Layers['p'][2*ii*vector_size:2*ii*vector_size+vector_size] - Layers['p'][2*ii*vector_size+vector_size:2*ii*vector_size+2*vector_size])

      #Backward
      loss.backward()
      reg.backward()
      
      #Update
      t += 1
      for namee in Layers.keys():
        g[namee] = Layers[namee].grad
        if (namee == 'W')*(mask!=None):
          g[namee] = g[namee]*mask
        m[namee] = beta1 * m[namee] + (1 - beta1) * g[namee]
        v[namee] = beta2 * v[namee] + (1 - beta2) * torch.square(g[namee])
        mh[namee] = m[namee] / (1 - np.power(beta1, t)) + (1 - beta1) * g[namee] / (1 - np.power(beta1, t))
        vh[namee] = v[namee] / (1 - np.power(beta2, t))
        Layers[namee].data -= step_size * mh[namee] / (torch.sqrt(vh[namee]) + epsilon)
        Layers[namee].grad.data.zero_()
  train_loss, train_acc, val_loss, val_acc = print_progress(Layers, t_train_x, t_train_y, t_valid_x, t_valid_y, max_depth=max_depth, epoch_index=epoch_index, verbose=verbose)
  loss_array= np.append(loss_array, train_loss)
  acc_array = np.append(acc_array, train_acc)
  val_loss_array= np.append(val_loss_array, val_loss)
  val_acc_array = np.append(val_acc_array, val_acc)

  if verbose:
    print("\nFinish training\n")

  if graphing:
    plt.imshow(np.abs(Layers["W"].cpu().detach().numpy()), cmap='Greys')
    plt.title('Absolute Value Intensity of All Nodes')
    plt.colorbar()
    plt.show()

    plt.plot(100*(acc_array), label='Train')
    plt.plot(100*(val_acc_array), label='Validation')
    plt.title('Accuracy')
    plt.ylabel('Accuracy Percentage')
    plt.xlabel('Epochs')
    plt.legend()
    plt.show()

    plt.plot(loss_array, label='Train')
    plt.plot(val_loss_array, label='Validation')
    plt.title('Cross Entropy Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend()
    plt.show()
  
  return Layers

# %%
def create_mask(W):
  mask = torch.zeros_like(W, device=device, requires_grad=False)
  mask[torch.argmax(torch.abs(W), dim=0),torch.arange(W.shape[1])] = 1
  return mask

# %% [markdown]
# # Vanilla Soft Decision Tree (SDT)

# %%
#Input max_depth for model
max_depth = 4

mask = None
reg_l = 0

#Input for training
minibatch_size = 256
num_epoch = 8
num_step_per_epoch = 256
step_size = 1e-3

Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, 
                                  mask=mask, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, 
                                  num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=True, 
                                  graphing=True)
# Out:
# Start training
#
# # of Epochs: 8
# # of Steps per Epoch: 256
# Minibatch Size: 256
#
# Epoch 0 Summary:
# Train Loss: 0.8399821396720619
# Train Accuracy: 39.36%
# Valid Loss: 0.8413010259226686
# Valid Accuracy: 41.0%
#
# Epoch 1 Summary:
# Train Loss: 0.657707629240282
# Train Accuracy: 64.27%
# Valid Loss: 0.6607420095366279
# Valid Accuracy: 63.85%
#
# Epoch 2 Summary:
# Train Loss: 0.609019662803577
# Train Accuracy: 67.87%
# Valid Loss: 0.6106284799424325
# Valid Accuracy: 67.54%
#
# Epoch 3 Summary:
# Train Loss: 0.5895775423032399
# Train Accuracy: 69.29%
# Valid Loss: 0.5901744741440431
# Valid Accuracy: 69.33%
#
# Epoch 4 Summary:
# Train Loss: 0.57950340029659
# Train Accuracy: 70.11%
# Valid Loss: 0.5793415078298061
# Valid Accuracy: 70.18%
#
# Epoch 5 Summary:
# Train Loss: 0.5728656865230882
# Train Accuracy: 70.63%
# Valid Loss: 0.5718699638386971
# Valid Accuracy: 70.73%
#
# Epoch 6 Summary:
# Train Loss: 0.5688390753565925
# Train Accuracy: 70.91%
# Valid Loss: 0.5672017732577948
# Valid Accuracy: 71.04%
#
# Epoch 7 Summary:
# Train Loss: 0.5658705580166064
# Train Accuracy: 71.15%
# Valid Loss: 0.5633741263649279
# Valid Accuracy: 71.32%
#
# Epoch 7 Summary:
# Train Loss: 0.5638599297739303
# Train Accuracy: 71.29%
# Valid Loss: 0.560717734251529
# Valid Accuracy: 71.55%
#
# Finish training

# %%
find_roc_auc_after_training(t_test_x, t_test_y, Layers, threholsd_part=1e-2)
# Out:
# 0.7083357960148717

# %% [markdown]
# # Vanilal Soft decision tree with noise

# %%
#Input max_depth for model
max_depth = 4

mask = None
reg_l = 0

#Input for training
minibatch_size = 128
num_epoch = 10
num_step_per_epoch = 256
step_size = 1e-4

torch.tensor(np.random.uniform(0, 0.2, t_train_y.shape))

Layers = soft_decision_tree_train(max_depth, t_train_x, torch.abs(t_train_y-torch.tensor(np.random.uniform(0, 0.2, t_train_y.shape), device=device, dtype=torch.float32, requires_grad=False)), t_valid_x, t_valid_y, 
                                  mask=mask, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, 
                                  num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=False, 
                                  graphing=True)
print("AUC-ROC Score: {}".format(find_roc_auc_after_training(t_valid_x, t_valid_y, Layers, threholsd_part=1e-2)))

Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y*0.8+0.1, t_valid_x, t_valid_y, 
                                  mask=mask, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, 
                                  num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=False, 
                                  graphing=True)
print("AUC-ROC Score: {}".format(find_roc_auc_after_training(t_valid_x, t_valid_y, Layers, threholsd_part=1e-2)))


Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, 
                                  mask=mask, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, 
                                  num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=False, 
                                  graphing=True)
print("AUC-ROC Score: {}".format(find_roc_auc_after_training(t_valid_x, t_valid_y, Layers, threholsd_part=1e-2)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-3e24888ce6f7> in <module>
#      16                                   mask=mask, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size,
#      17                                   num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=False,
# ---> 18                                   graphing=True)
#      19 print("AUC-ROC Score: {}".format(find_roc_auc_after_training(t_valid_x, t_valid_y, Layers, threholsd_part=1e-2)))
#      20
#
# <ipython-input-42-7f55c31fdd37> in soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask, pretrained_Layers, step_size, reg_l, minibatch_size, num_epoch, num_step_per_epoch, beta1, beta2, epsilon, verbose, graphing)
#      34     for step_index in range(num_step_per_epoch):
#      35       #Minibatch
# ---> 36       index = torch.randperm(t_train_x.shape[0])[:minibatch_size]
#      37
#      38       #Forward
#
# KeyboardInterrupt:

# %% [markdown]
# # Soft Decision Tree with L1-Reg (HRSDT)

# %%
#Input max_depth for model
max_depth = 4

mask = None
reg_l = 1e-2

#Input for training
minibatch_size = 137
num_epoch = 5
num_step_per_epoch = 501
step_size = 1e-3

Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask=mask, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=True, graphing=True)
# Out:
# Start training
#
# # of Epochs: 5
# # of Steps per Epoch: 501
# Minibatch Size: 137
#
# Epoch 0 Summary:
# Train Loss: 0.7269960244115752
# Train Accuracy: 50.51%
# Valid Loss: 0.7172682576586128
# Valid Accuracy: 52.29%
#
# Epoch 1 Summary:
# Train Loss: 0.6067730551304675
# Train Accuracy: 68.71%
# Valid Loss: 0.6000201537523984
# Valid Accuracy: 69.45%
#
# Epoch 2 Summary:
# Train Loss: 0.5822233257134948
# Train Accuracy: 70.55%
# Valid Loss: 0.5751110314902105
# Valid Accuracy: 71.15%
#
# Epoch 3 Summary:
# Train Loss: 0.5706694274180312
# Train Accuracy: 71.26%
# Valid Loss: 0.5631190054736679
# Valid Accuracy: 71.94%
#
# Epoch 4 Summary:
# Train Loss: 0.5644985978269315
# Train Accuracy: 71.51%
# Valid Loss: 0.5573176665973408
# Valid Accuracy: 72.22%
#
# Epoch 4 Summary:
# Train Loss: 0.5619253321642197
# Train Accuracy: 71.6%
# Valid Loss: 0.5552365715076653
# Valid Accuracy: 72.37%
#
# Finish training

# %% [markdown]
# # Let look at a case when we keep only the biggest parameters

# %%
mask = create_mask(Layers['W'].data)
Layers['W'].data *= mask

# %%
plt.imshow(np.abs(Layers["W"].cpu().detach().numpy()), cmap='Greys')
plt.title('Absolute Value Intensity of All Nodes')
plt.colorbar()
plt.show()

train_loss, train_acc, val_loss, val_acc = print_progress(Layers, t_train_x, t_train_y, t_valid_x, t_valid_y, max_depth=None, epoch_index=None, verbose=True)
# Out:
# Train Loss: 0.5822970590459332
# Train Accuracy: 70.0%
# Valid Loss: 0.5725315294148029
# Valid Accuracy: 71.3%

# %% [markdown]
# # Retrain with only 1 feature per node

# %% [markdown]
# Note that the feature selction is embedded within the matrix mask

# %%
mask = mask
reg_l = 1e-2

Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask=mask, pretrained_Layers=Layers, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=True, graphing=True)
# Out:
# Start training
#
# # of Epochs: 5
# # of Steps per Epoch: 501
# Minibatch Size: 137
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-83-7d09f16345f7> in <module>
#      11 step_size = 1e-3
#      12
# ---> 13 Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask=mask, pretrained_Layers=Layers, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=True, graphing=True)
#
# <ipython-input-42-7f55c31fdd37> in soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask, pretrained_Layers, step_size, reg_l, minibatch_size, num_epoch, num_step_per_epoch, beta1, beta2, epsilon, verbose, graphing)
#      27   for epoch_index in range(num_epoch):
#      28     #Print progress
# ---> 29     train_loss, train_acc, val_loss, val_acc = print_progress(Layers, t_train_x, t_train_y, t_valid_x, t_valid_y, max_depth=max_depth, epoch_index=epoch_index, verbose=verbose)
#      30     loss_array= np.append(loss_array, train_loss)
#      31     acc_array = np.append(acc_array, train_acc)
#
# <ipython-input-41-b02b5e6ce1ad> in print_progress(Layers, t_train_x, t_train_y, t_valid_x, t_valid_y, max_depth, epoch_index, verbose)
#       1 def print_progress(Layers, t_train_x, t_train_y, t_valid_x, t_valid_y, max_depth=None, epoch_index=None, verbose=True):
#       2   #Eval Train
# ----> 3   prob = forward(t_train_x, Layers, max_depth=max_depth, requires_grad=False)
#       4   train_loss = float(find_loss(prob, t_train_y))
#       5   train_acc = float(find_accuracy(prob, t_train_y))
#
# <ipython-input-38-c5fb6f4c0ea9> in forward(input, Layers, max_depth, requires_grad)
#      11       dist = torch.cat((temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1), (1-temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1))), dim=2).reshape(input.shape[0],-1).unsqueeze(-1).repeat(1,1,2**(max_depth-1-i)).reshape(input.shape[0],-1)
#      12     else:
# ---> 13       dist *= torch.cat((temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1), (1-temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1))), dim=2).reshape(input.shape[0],-1).unsqueeze(-1).repeat(1,1,2**(max_depth-1-i)).reshape(input.shape[0],-1)
#      14   if requires_grad:
#      15     score = dist@Layers['p']
#
# RuntimeError: The size of tensor a (32) must match the size of tensor b (0) at non-singleton dimension 1

# %%
#Input max_depth for model
max_depth = 4

mask = mask
reg_l = 1e-2

#Input for training
minibatch_size = 137
num_epoch = 5
num_step_per_epoch = 501
step_size = 1e-3

Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask=mask, pretrained_Layers=None, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=True, graphing=True)
# Out:
# Start training
#
# # of Epochs: 5
# # of Steps per Epoch: 501
# Minibatch Size: 137
#
# Epoch 0 Summary:
# Train:
# Loss: 0.7072270079323262
# Accuracy: 53.1%
# Valid:
# Loss: 0.6805646802305175
# Accuracy: 58.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-139-e6a1ae71a9ea> in <module>()
#      11 step_size = 1e-3
#      12
# ---> 13 Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask=mask, pretrained_Layers=None, step_size=step_size, reg_l=reg_l, minibatch_size=minibatch_size, num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=True, graphing=True)
#
# <ipython-input-13-7f55c31fdd37> in soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask, pretrained_Layers, step_size, reg_l, minibatch_size, num_epoch, num_step_per_epoch, beta1, beta2, epsilon, verbose, graphing)
#      49         num_pairs = np.int(np.power(2, (max_depth-i-1)))
#      50         for ii in range(num_pairs):
# ---> 51           reg += reg_w * torch.linalg.norm(Layers['p'][2*ii*vector_size:2*ii*vector_size+vector_size] - Layers['p'][2*ii*vector_size+vector_size:2*ii*vector_size+2*vector_size])
#      52
#      53       #Backward
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize SDT

# %%
import scipy.stats as st
import math
feature_names = train_x.columns
def inverse_sigmoid(y):
    return np.log(y/(1-y))
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

def visualize_soft_decision_tree(layers):
    W = layers['W'].cpu().detach().numpy()
    b = layers['b'].cpu().detach().numpy()
    p = layers['p'].cpu().detach().numpy()
    assert(np.count_nonzero(W)==W.shape[1])
    plt.imshow(np.abs(W), cmap='Greys')
    plt.show()


    num_levels = int(np.log(W.shape[1]+1)/np.log(2))
    leaf_nodes = (W.shape[1]+1)//2
    
    train_xx = t_train_x.cpu().detach().numpy()
    probs = sigmoid(t_train_x.cpu().detach().numpy()@W + b)
    
    feature_idxs = np.argmax(np.abs(W), axis = 0)   
    threshold = - b/np.sum(W, axis =0)
    fig, axes = plt.subplots(num_levels, leaf_nodes, figsize = (3*leaf_nodes, 1*num_levels))
    
    ax_idx = 0
    for i in range(W.shape[1]):
      f_i = feature_idxs[i]
      percentile = st.norm.cdf(x=threshold[i],loc=mu[f_i],scale=sigmaa[f_i])*100
      
      for j in range(2**(num_levels-ax_idx//leaf_nodes-1)):
        axes[ax_idx//leaf_nodes][ax_idx%leaf_nodes].scatter(train_xx[:, f_i], np.random.uniform(0, 0.5, size = (train_xx.shape[0], )), s = 1)
        axes[ax_idx//leaf_nodes][ax_idx%leaf_nodes].axvline(threshold[i],c = "red",lw =3 )
        axes[ax_idx//leaf_nodes][ax_idx%leaf_nodes].set_title(feature_names[f_i]+" above "+str(round(percentile))+"%")
        ax_idx+=1
    plt.tight_layout()
    plt.show()  
    print(p)

visualize_soft_decision_tree(Layers)
# Out:
# [ 0.76940566 -1.43769246  0.85577099 -0.24531037  2.35963897  0.55428892
#   1.40286617 -0.23194506  1.23059825  0.42062182  1.02562     1.24627499
#  -0.50048761 -0.07368604  1.05141501  0.48825306]

# %%
plt.hist(np.array(train_x)[:, 1]*prob)
# Out:
# (array([436.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 564.]),
#  array([-1.13678688, -0.93522892, -0.73367096, -0.53211301, -0.33055505,
#         -0.12899709,  0.07256086,  0.27411882,  0.47567678,  0.67723474,
#          0.87879269]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Train SSDT Function

# %%
def ssdt_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, step_size=1e-3, reg_l_1=1e-2, reg_l_2=5e-4, minibatch_size=128, num_epoch=20, num_step_per_epoch=500, verbose=False, graphing=False):
  Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, step_size=step_size, reg_l=reg_l_1, minibatch_size=minibatch_size, num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=verbose, graphing=graphing)
  mask = create_mask(Layers['W'].data)
  Layers['W'].data *= mask
  Layers = soft_decision_tree_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, mask=mask, pretrained_Layers=Layers, step_size=step_size, reg_l=reg_l_2, minibatch_size=minibatch_size, num_epoch=num_epoch, num_step_per_epoch=num_step_per_epoch, verbose=verbose, graphing=graphing)
  return Layers

# %%
Layers = ssdt_train(max_depth, t_train_x, t_train_y, t_valid_x, t_valid_y, step_size=1e-3, reg_l_1=1e-2, reg_l_2=5e-4, minibatch_size=128, num_epoch=20, num_step_per_epoch=500, verbose=False, graphing=False)

plt.imshow(np.abs(Layers["W"].cpu().detach().numpy()), cmap='Greys')
plt.title('Absolute Value Intensity of All Nodes')
plt.colorbar()
plt.show()

# %%
o_label = np.where(train_y == 0)[0]
one_label = np.where(train_y == 1)[0]

# %%
num_layers = Layers['W'].shape[1]
for i in range(num_layers):
  f_i = int(torch.argmax(torch.abs(Layers['W'][:,i])))
  sns.distplot(np.array(train_x)[o_label,f_i], hist=False)
  sns.distplot(np.array(train_x)[one_label,f_i], hist=False)
  threshold = float(- Layers['b'][i] /  torch.sum(Layers['W'][:,i]))
  plt.axvline(threshold)
  plt.show()

# %%
temp = torch.sigmoid(t_train_x@Layers['W'].data + Layers['b'].data)
dist = None
for i in range(max_depth):
  if dist == None:
    dist = torch.cat((temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1), (1-temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1))), dim=2).reshape(t_train_x.shape[0],-1).unsqueeze(-1)\
    .repeat(1,1,2**(max_depth-1-i)).reshape(t_train_x.shape[0],-1)
  else:
    dist *= torch.cat((temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1), (1-temp[:,2**i - 1: 2**(i+1) - 1].unsqueeze(-1))), dim=2).reshape(t_train_x.shape[0],-1).unsqueeze(-1).\
    repeat(1,1,2**(max_depth-1-i)).reshape(t_train_x.shape[0],-1)

Big_prob_array = torch.zeros((dist.shape[0], (dist.shape[1]-1)), device=device, dtype=torch.float64)
for i in range(max_depth):
  Big_prob_array[:,2**(i)-1:2**(i+1)-1] = torch.sum(dist.reshape(2**i * t_train_x.shape[0],2**(max_depth-i)), dim=1).unsqueeze(dim=-1).reshape(2**i,t_train_x.shape[0]).T

# %%
Big_prob_array = Big_prob_array.cpu().detach().numpy()
Big_prob_array.shape
# Out:
# (1000, 15)

# %%
weight_i = Big_prob_array[:,i] #probability of reaching to node for each example

for i in range(num_layers):
  f_i = int(torch.argmax(torch.abs(Layers['W'][:,i])))
  threshold = float(- Layers['b'][i] /  torch.sum(Layers['W'][:,i]))

  min_val = 0
  max_val = 100

  sns.distplot(np.array(train_x)[o_label,f_i], hist=True, hist_kws={'weights': weight_i[o_label]}, kde=False, norm_hist=True, color="blue")
  sns.distplot(np.array(train_x)[one_label,f_i], hist=True, hist_kws={'weights': weight_i[one_label]}, kde=False, norm_hist=True, color="orange")
  # plt.axvline(threshold)
  # plt.show()


  sns.distplot(np.array(train_x)[o_label,f_i], hist=False, color="blue")
  sns.distplot(np.array(train_x)[one_label,f_i], hist=False, color="orange")
  threshold = float(- Layers['b'][i] /  torch.sum(Layers['W'][:,i]))
  plt.axvline(threshold)
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
